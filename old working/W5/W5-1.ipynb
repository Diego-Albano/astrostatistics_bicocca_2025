# %%
import numpy as np
import pylab as plt
from scipy.stats import norm

# %%
mean = 1
std = 0.2
N = 8

sample = np.random.normal(loc=mean, scale=std, size=N)
print(sample)

lin = np.linspace(0, 2, 10000)

L = []

for i in sample:
    L.append(norm.pdf(lin ,loc=i ,scale=std))

#print(L)

likelihood = np.prod(L ,axis=0)

for i in L:
    plt.plot(lin, i)
    
plt.plot(lin, likelihood)
# Out:
# [1.24032261 0.82735957 1.15524089 1.38311333 0.81182332 0.87648878
#  0.93842501 1.09304731]

# %%
print(lin[np.argsort(likelihood)[-1]])
print(np.mean(sample))
# Out:
# 1.0407040704070407
# 1.0407276021388685

# %%
max = np.argsort(likelihood)[-1]
print(max)
# Out:
# 5203

# %%
std_mean = 1/np.sqrt(-np.diff(np.log(likelihood), n=2)/(lin[1] - lin[0])**2)[max]
print(std_mean)
# Out:
# 0.07071067812687236

# %%
print(std/N**0.5)
# Out:
# 0.07071067811865475

# %%
plt.plot(lin, likelihood)

new_gaussian = norm.pdf(lin ,loc=np.mean(sample), scale=std/N**0.5)
plt.plot(lin, new_gaussian)   #1 works sometimes
